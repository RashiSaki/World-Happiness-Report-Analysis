# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_2019 = pd.read_csv('2019.csv')

df_2018 = pd.read_csv('2018.csv')

df_2017 = pd.read_csv('2017.csv')

df_2016 = pd.read_csv('2016.csv')

df_2015 = pd.read_csv('2015.csv')

# %%
#pd.read_table('2019 World Happiness Report.csv')
#pd.read_csv is more efficient, as your csv has commas that need to be seperated to make the data look cleaner

# %%
df_2019.columns = df_2019.columns.str.replace(' ', '_')

df_2018.columns = df_2018.columns.str.replace(' ', '_')

df_2017.columns = df_2017.columns.str.replace('.', '_')

df_2016.columns = df_2016.columns.str.replace(' ', '_')

df_2015.columns = df_2015.columns.str.replace(' ', '_')
# Out:
# <ipython-input-67-8a32065b4dc2>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_2017.columns = df_2017.columns.str.replace('.', '_')

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df_2019['Year'] = 2019

df_2018['Year'] = 2018

df_2017['Year'] = 2017

df_2016['Year'] = 2016

df_2015['Year'] = 2015

# %%
df_2019.shape
# Out:
# (156, 10)

# %%
df_2019.rename(columns = {'Country_or_region' : 'Country', 'Score': 'Happiness_score', }, inplace = True)

# %%
continent_dict = { 
    'Asia': ['Afghanistan', 'Bahrain', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Pakistan', 'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates', 'Yemen','Taiwan', 'Singapore', 'Uzbekistan', 'Thailand', 'South Korea', 'Japan', 'Philippines', 'Tajikistan', 'Hong Kong', 'Malaysia', 'Mongolia', 'Kyrgyzstan', 'Turkmenistan', 'Azerbaijan', 'Indonesia', 'China', 'Vietnam', 'Bhutan', 'Nepal', 'Laos', 'Cambodia', 'Palestinian Territories', 'Armenia', 'Georgia', 'Bangladesh', 'Sri Lanka', 'Myanmar', 'India'],
    'Africa': ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)','Congo (Kinshasa)', 'Democratic Republic of the Congo', 'Republic of the Congo', 'Cote d\'Ivoire', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau','Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan','Swaziland', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
    'North America': ['Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'United States'],
    'South America': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Trinidad & Tobago', 'Uruguay', 'Venezuela'],
    'Europe': ['Albania', 'Andorra', 'Austria','Azerbaijan', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece','Georgia', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands','Northern Cyprus', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican City'],
    'Oceania': ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']
    }

# %%
df_2019['Continent'] = df_2019['Country'].apply(lambda x: next((k for k in continent_dict if x in continent_dict[k]), None))
df_2019.head()
# Out:
#    Overall_rank      Country  Happiness_score  GDP_per_capita  Social_support  \
# 0             1      Finland            7.769           1.340           1.587
# 1             2      Denmark            7.600           1.383           1.573
# 2             3       Norway            7.554           1.488           1.582
# 3             4      Iceland            7.494           1.380           1.624
# 4             5  Netherlands            7.488           1.396           1.522
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions_of_corruption  Year Continent
# 0                      0.393  2019    Europe
# 1                      0.410  2019    Europe
# 2                      0.341  2019    Europe
# 3                      0.118  2019    Europe
# 4                      0.298  2019    Europe

# %%
#df_2019.set_index('Country', inplace = True)

# %%
#df_2019.head()

# %%
#df_2019.index.name = None
#df_2019.head()

# %%
df_2019.head()
# Out:
#    Overall_rank      Country  Happiness_score  GDP_per_capita  Social_support  \
# 0             1      Finland            7.769           1.340           1.587
# 1             2      Denmark            7.600           1.383           1.573
# 2             3       Norway            7.554           1.488           1.582
# 3             4      Iceland            7.494           1.380           1.624
# 4             5  Netherlands            7.488           1.396           1.522
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions_of_corruption  Year Continent
# 0                      0.393  2019    Europe
# 1                      0.410  2019    Europe
# 2                      0.341  2019    Europe
# 3                      0.118  2019    Europe
# 4                      0.298  2019    Europe

# %%
df_2019 = df_2019[['Country','Overall_rank','Year','Continent','Happiness_score','GDP_per_capita','Social_support','Healthy_life_expectancy', 'Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']]

# %%
df_2019.head()
# Out:
#        Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 0      Finland             1  2019    Europe            7.769           1.340
# 1      Denmark             2  2019    Europe            7.600           1.383
# 2       Norway             3  2019    Europe            7.554           1.488
# 3      Iceland             4  2019    Europe            7.494           1.380
# 4  Netherlands             5  2019    Europe            7.488           1.396
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions_of_corruption
# 0       0.153                      0.393
# 1       0.252                      0.410
# 2       0.271                      0.341
# 3       0.354                      0.118
# 4       0.322                      0.298

# %%
df_2019.columns
# Out:
# Index(['Country', 'Overall_rank', 'Year', 'Continent', 'Happiness_score',
#        'GDP_per_capita', 'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df_2019.dtypes
# Out:
# Country                          object
# Overall_rank                      int64
# Year                              int64
# Continent                        object
# Happiness_score                 float64
# GDP_per_capita                  float64
# Social_support                  float64
# Healthy_life_expectancy         float64
# Freedom_to_make_life_choices    float64
# Generosity                      float64
# Perceptions_of_corruption       float64
# dtype: object

# %%
#missing_data_2019 = df_2019.isnull()
#missing_data_2019

# %%
missing_data_2019 = df_2019.isnull().sum()
missing_data_2019
# Out:
# Country                         0
# Overall_rank                    0
# Year                            0
# Continent                       0
# Happiness_score                 0
# GDP_per_capita                  0
# Social_support                  0
# Healthy_life_expectancy         0
# Freedom_to_make_life_choices    0
# Generosity                      0
# Perceptions_of_corruption       0
# dtype: int64

# %%
zero_val_2019 = (df_2019 == 0).sum()
zero_val_2019
# Out:
# Country                         0
# Overall_rank                    0
# Year                            0
# Continent                       0
# Happiness_score                 0
# GDP_per_capita                  1
# Social_support                  1
# Healthy_life_expectancy         1
# Freedom_to_make_life_choices    1
# Generosity                      1
# Perceptions_of_corruption       1
# dtype: int64

# %%
df_2018.shape
# Out:
# (156, 10)

# %%
df_2018
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions_of_corruption  Year
# 0         0.202                      0.393  2018
# 1         0.286                      0.340  2018
# 2         0.284                      0.408  2018
# 3         0.353                      0.138  2018
# 4         0.256                      0.357  2018
# ..          ...                        ...   ...
# 151       0.083                      0.064  2018
# 152       0.270                      0.097  2018
# 153       0.224                      0.106  2018
# 154       0.218                      0.038  2018
# 155       0.149                      0.076  2018
#
# [156 rows x 10 columns]

# %%
df_2018.rename(columns = {'Score': 'Hapiness_Score','Country_or_region':'Country','Hapiness_Score':'Happiness_Score'}, inplace=True)

# %%
continent_dict1 = { 
    'Asia': ['Afghanistan', 'Bahrain', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Pakistan', 'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates', 'Yemen','Taiwan', 'Singapore', 'Uzbekistan', 'Thailand', 'South Korea', 'Japan', 'Philippines', 'Tajikistan', 'Hong Kong', 'Malaysia', 'Mongolia', 'Kyrgyzstan', 'Turkmenistan', 'Azerbaijan', 'Indonesia', 'China', 'Vietnam', 'Bhutan', 'Nepal', 'Laos', 'Cambodia', 'Palestinian Territories', 'Armenia', 'Georgia', 'Bangladesh', 'Sri Lanka', 'Myanmar', 'India'],
    'Africa': ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)','Congo (Kinshasa)', 'Democratic Republic of the Congo', 'Republic of the Congo', 'Cote d\'Ivoire', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau','Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan','Swaziland', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
    'North America': ['Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'United States'],
    'South America': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Trinidad & Tobago', 'Uruguay', 'Venezuela'],
    'Europe': ['Albania', 'Andorra', 'Austria','Azerbaijan', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece','Georgia', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands','Northern Cyprus', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican City'],
    'Oceania': ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']
    }

# %%
df_2018['Continent'] = df_2018['Country'].apply(lambda x: next((k for k in continent_dict if x in continent_dict[k]), None))
df_2018.head()
# Out:
#    Overall_rank      Country  Happiness_Score  GDP_per_capita  Social_support  \
# 0             1      Finland            7.632           1.305           1.592
# 1             2       Norway            7.594           1.456           1.582
# 2             3      Denmark            7.555           1.351           1.590
# 3             4      Iceland            7.495           1.343           1.644
# 4             5  Switzerland            7.487           1.420           1.549
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions_of_corruption  Year Continent
# 0                      0.393  2018    Europe
# 1                      0.340  2018    Europe
# 2                      0.408  2018    Europe
# 3                      0.138  2018    Europe
# 4                      0.357  2018    Europe

# %%
df_2018 = df_2018 [['Country','Overall_rank','Year','Continent','Happiness_Score','GDP_per_capita','Social_support','Healthy_life_expectancy','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']]

# %%
df_2017.rename(columns = {'Happiness_Rank': 'Overall_rank', 'Economy__GDP_per_Capita_': 'GDP_per_capita', 'Family': 'Social_support','Freedom': 'Freedom_to_make_life_choices','Trust__Government_Corruption_': 'Perceptions_of_corruption','Health__Life_Expectancy_':'Healthy_life_expectancy'}, inplace=True)

# %%
df_2017 = df_2017 [['Country','Overall_rank','Year','Happiness_Score','GDP_per_capita','Social_support','Healthy_life_expectancy','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']]

# %%
df_2017.head()
# Out:
#        Country  Overall_rank  Year  Happiness_Score  GDP_per_capita  \
# 0       Norway             1  2017            7.537        1.616463
# 1      Denmark             2  2017            7.522        1.482383
# 2      Iceland             3  2017            7.504        1.480633
# 3  Switzerland             4  2017            7.494        1.564980
# 4      Finland             5  2017            7.469        1.443572
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0        1.533524                 0.796667                      0.635423
# 1        1.551122                 0.792566                      0.626007
# 2        1.610574                 0.833552                      0.627163
# 3        1.516912                 0.858131                      0.620071
# 4        1.540247                 0.809158                      0.617951
#
#    Generosity  Perceptions_of_corruption
# 0    0.362012                   0.315964
# 1    0.355280                   0.400770
# 2    0.475540                   0.153527
# 3    0.290549                   0.367007
# 4    0.245483                   0.382612

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy_(GDP_per_Capita)   Family  Health_(Life_Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust_(Government_Corruption)  Generosity  Dystopia_Residual  Year
# 0                        0.44453     0.36171            2.73939  2016
# 1                        0.41203     0.28083            2.69463  2016
# 2                        0.14975     0.47678            2.83137  2016
# 3                        0.35776     0.37895            2.66465  2016
# 4                        0.41004     0.25492            2.82596  2016

# %%
df_2016.drop(['Lower_Confidence_Interval','Upper_Confidence_Interval','Dystopia_Residual','Region'], axis = 1, inplace = True)

# %%
df_2016.rename(columns = {'Happiness_Rank': 'Overall_rank', 'Economy_(GDP_per_Capita)': 'GDP_per_capita', 'Family': 'Social_support','Freedom': 'Freedom_to_make_life_choices','Trust_(Government_Corruption)': 'Perceptions_of_corruption','Health_(Life_Expectancy)':'Healthy_life_expectancy'}, inplace=True)

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard_Error  Economy_(GDP_per_Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health_(Life_Expectancy)  Freedom  Trust_(Government_Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia_Residual  Year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015
# 2     0.34139            2.49204  2015
# 3     0.34699            2.46531  2015
# 4     0.45811            2.45176  2015

# %%
df_2015.drop(['Region','Standard_Error','Dystopia_Residual'], axis = 1, inplace = True)

# %%
df_2015.rename(columns = {'Happiness_Rank': 'Overall_rank', 'Economy_(GDP_per_Capita)': 'GDP_per_capita', 'Family': 'Social_support','Freedom': 'Freedom_to_make_life_choices','Trust_(Government_Corruption)': 'Perceptions_of_corruption','Health_(Life_Expectancy)':'Healthy_life_expectancy'}, inplace=True)

# %%
df_2019 = df_2019.sort_values(by=['Happiness_score'], ascending = False)
df_2019
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 0                     Finland             1  2019    Europe            7.769
# 1                     Denmark             2  2019    Europe            7.600
# 2                      Norway             3  2019    Europe            7.554
# 3                     Iceland             4  2019    Europe            7.494
# 4                 Netherlands             5  2019    Europe            7.488
# ..                        ...           ...   ...       ...              ...
# 151                    Rwanda           152  2019    Africa            3.334
# 152                  Tanzania           153  2019    Africa            3.231
# 153               Afghanistan           154  2019      Asia            3.203
# 154  Central African Republic           155  2019    Africa            3.083
# 155               South Sudan           156  2019    Africa            2.853
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 0             1.340           1.587                    0.986
# 1             1.383           1.573                    0.996
# 2             1.488           1.582                    1.028
# 3             1.380           1.624                    1.026
# 4             1.396           1.522                    0.999
# ..              ...             ...                      ...
# 151           0.359           0.711                    0.614
# 152           0.476           0.885                    0.499
# 153           0.350           0.517                    0.361
# 154           0.026           0.000                    0.105
# 155           0.306           0.575                    0.295
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 151                         0.555       0.217                      0.411
# 152                         0.417       0.276                      0.147
# 153                         0.085       0.158                      0.025
# 154                         0.225       0.235                      0.035
# 155                         0.010       0.202                      0.091
#
# [156 rows x 11 columns]

# %%
df_2019.groupby('Continent')['Happiness_score'].describe()
# Out:
#                count      mean       std    min      25%     50%      75%  \
# Continent
# Africa          45.0  4.368289  0.643687  2.853  3.97500  4.4610  4.72200
# Asia            43.0  5.224442  0.886827  3.203  4.62750  5.2080  5.89050
# Europe          43.0  6.245000  0.861794  4.332  5.62550  6.1180  7.00300
# North America   12.0  6.151583  0.971130  3.597  5.88250  6.2870  6.66925
# Oceania          2.0  7.267500  0.055861  7.228  7.24775  7.2675  7.28725
# South America   11.0  5.944909  0.477370  4.707  5.76100  6.0860  6.24250
#
#                  max
# Continent
# Africa         5.888
# Asia           7.139
# Europe         7.769
# North America  7.278
# Oceania        7.307
# South America  6.444

# %%
df_2019.groupby('Continent').mean()
# Out:
# <ipython-input-86-2d3c445f12b3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_2019.groupby('Continent').mean()
#                Overall_rank    Year  Happiness_score  GDP_per_capita  \
# Continent
# Africa           122.266667  2019.0         4.368289        0.498467
# Asia              85.627907  2019.0         5.224442        0.962651
# Europe            45.023256  2019.0         6.245000        1.220814
# North America     45.000000  2019.0         6.151583        0.929167
# Oceania            9.500000  2019.0         7.267500        1.337500
# South America     51.545455  2019.0         5.944909        1.005273
#
#                Social_support  Healthy_life_expectancy  \
# Continent
# Africa               0.932244                 0.444467
# Asia                 1.189279                 0.756000
# Europe               1.425209                 0.921047
# North America        1.317250                 0.825333
# Oceania              1.552500                 1.031000
# South America        1.389909                 0.823455
#
#                Freedom_to_make_life_choices  Generosity  \
# Continent
# Africa                             0.329378    0.175244
# Asia                               0.405721    0.214047
# Europe                             0.407767    0.174000
# North America                      0.455417    0.187083
# Oceania                            0.571000    0.331000
# South America                      0.439273    0.123364
#
#                Perceptions_of_corruption
# Continent
# Africa                          0.094311
# Asia                            0.113000
# Europe                          0.128651
# North America                   0.104333
# Oceania                         0.335000
# South America                   0.063364

# %%
grouped_score_2019 = df_2019.groupby('Continent')['Happiness_score']
mean_scores_2019 = grouped_score_2019.mean()

# %%
mean_scores_2019.sort_values(ascending=False)
# Out:
# Continent
# Oceania          7.267500
# Europe           6.245000
# North America    6.151583
# South America    5.944909
# Asia             5.224442
# Africa           4.368289
# Name: Happiness_score, dtype: float64

# %%
df_2019_africa = df_2019[df_2019['Continent']=='Africa']

# %%
df_2019_africa.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#       Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 56  Mauritius            57  2019    Africa            5.888           1.120
# 71      Libya            72  2019    Africa            5.525           1.044
# 84    Nigeria            85  2019    Africa            5.265           0.696
# 87    Algeria            88  2019    Africa            5.211           1.002
# 88    Morocco            89  2019    Africa            5.208           0.801
#
#     Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 56           1.402                    0.798                         0.498
# 71           1.303                    0.673                         0.416
# 84           1.111                    0.245                         0.426
# 87           1.160                    0.785                         0.086
# 88           0.782                    0.782                         0.418
#
#     Generosity  Perceptions_of_corruption
# 56       0.215                      0.060
# 71       0.133                      0.152
# 84       0.215                      0.041
# 87       0.073                      0.114
# 88       0.036                      0.076

# %%
df_2019_africa.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count     45.000000    45.0        45.000000       45.000000       45.000000
# mean     122.266667  2019.0         4.368289        0.498467        0.932244
# std       23.230466     0.0         0.643687        0.313846        0.272437
# min       57.000000  2019.0         2.853000        0.000000        0.000000
# 25%      106.000000  2019.0         3.975000        0.275000        0.782000
# 50%      124.000000  2019.0         4.461000        0.393000        0.983000
# 75%      141.000000  2019.0         4.722000        0.696000        1.125000
# max      156.000000  2019.0         5.888000        1.120000        1.402000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                45.000000                     45.000000   45.000000
# mean                  0.444467                      0.329378    0.175244
# std                   0.178937                      0.122337    0.075080
# min                   0.000000                      0.010000    0.025000
# 25%                   0.357000                      0.269000    0.130000
# 50%                   0.443000                      0.352000    0.187000
# 75%                   0.538000                      0.416000    0.218000
# max                   0.815000                      0.559000    0.372000
#
#        Perceptions_of_corruption
# count                  45.000000
# mean                    0.094311
# std                     0.066093
# min                     0.033000
# 25%                     0.055000
# 50%                     0.085000
# 75%                     0.100000
# max                     0.411000

# %%
df_2019_asia = df_2019[df_2019['Continent']=='Asia']

# %%
df_2019_asia.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#                  Country  Overall_rank  Year Continent  Happiness_score  \
# 12                Israel            13  2019      Asia            7.139
# 20  United Arab Emirates            21  2019      Asia            6.825
# 24                Taiwan            25  2019      Asia            6.446
# 27          Saudi Arabia            28  2019      Asia            6.375
# 28                 Qatar            29  2019      Asia            6.374
#
#     GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 12           1.276           1.455                    1.029
# 20           1.503           1.310                    0.825
# 24           1.368           1.430                    0.914
# 27           1.403           1.357                    0.795
# 28           1.684           1.313                    0.871
#
#     Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 12                         0.371       0.261                      0.082
# 20                         0.598       0.262                      0.182
# 24                         0.351       0.242                      0.097
# 27                         0.439       0.080                      0.132
# 28                         0.555       0.220                      0.167

# %%
df_2019_asia.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count     43.000000    43.0        43.000000       43.000000       43.000000
# mean      85.627907  2019.0         5.224442        0.962651        1.189279
# std       37.832352     0.0         0.886827        0.350099        0.261967
# min       13.000000  2019.0         3.203000        0.287000        0.378000
# 25%       56.000000  2019.0         4.627500        0.725500        1.110000
# 50%       90.000000  2019.0         5.208000        0.948000        1.226000
# 75%      113.000000  2019.0         5.890500        1.248500        1.358500
# max      154.000000  2019.0         7.139000        1.684000        1.538000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                43.000000                     43.000000   43.000000
# mean                  0.756000                      0.407698    0.214047
# std                   0.175184                      0.150743    0.112749
# min                   0.361000                      0.013000    0.035000
# 25%                   0.657000                      0.315000    0.129500
# 50%                   0.769000                      0.440000    0.230000
# 75%                   0.829500                      0.526000    0.264000
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions_of_corruption
# count                   43.00000
# mean                     0.11300
# std                      0.08022
# min                      0.02300
# 25%                      0.06300
# 50%                      0.09800
# 75%                      0.14350
# max                      0.45300

# %%
df_2019_europe = df_2019[df_2019['Continent']=='Europe']

# %%
df_2019_europe.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#        Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 0      Finland             1  2019    Europe            7.769           1.340
# 1      Denmark             2  2019    Europe            7.600           1.383
# 2       Norway             3  2019    Europe            7.554           1.488
# 3      Iceland             4  2019    Europe            7.494           1.380
# 4  Netherlands             5  2019    Europe            7.488           1.396
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions_of_corruption
# 0       0.153                      0.393
# 1       0.252                      0.410
# 2       0.271                      0.341
# 3       0.354                      0.118
# 4       0.322                      0.298

# %%
df_2019_europe.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count     43.000000    43.0        43.000000       43.000000       43.000000
# mean      45.023256  2019.0         6.245000        1.220814        1.425209
# std       32.295871     0.0         0.861794        0.188430        0.147067
# min        1.000000  2019.0         4.332000        0.685000        0.848000
# 25%       16.500000  2019.0         5.625500        1.158500        1.372000
# 50%       44.000000  2019.0         6.118000        1.246000        1.475000
# 75%       69.000000  2019.0         7.003000        1.348000        1.517500
# max      133.000000  2019.0         7.769000        1.609000        1.624000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                43.000000                     43.000000   43.000000
# mean                  0.921047                      0.407767    0.174000
# std                   0.104933                      0.140581    0.092008
# min                   0.726000                      0.067000    0.000000
# 25%                   0.833000                      0.293500    0.107000
# 50%                   0.953000                      0.436000    0.158000
# 75%                   1.004000                      0.521000    0.256500
# max                   1.062000                      0.603000    0.375000
#
#        Perceptions_of_corruption
# count                  43.000000
# mean                    0.128651
# std                     0.128978
# min                     0.000000
# 25%                     0.028500
# 50%                     0.064000
# 75%                     0.218000
# max                     0.410000

# %%
df_2019_north_america = df_2019[df_2019['Continent']=='North America']

# %%
df_2019_north_america.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#           Country  Overall_rank  Year      Continent  Happiness_score  \
# 8          Canada             9  2019  North America            7.278
# 11     Costa Rica            12  2019  North America            7.167
# 18  United States            19  2019  North America            6.892
# 22         Mexico            23  2019  North America            6.595
# 26      Guatemala            27  2019  North America            6.436
#
#     GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 8            1.365           1.505                    1.039
# 11           1.034           1.441                    0.963
# 18           1.433           1.457                    0.874
# 22           1.070           1.323                    0.861
# 26           0.800           1.269                    0.746
#
#     Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 8                          0.584       0.285                      0.308
# 11                         0.558       0.144                      0.093
# 18                         0.454       0.280                      0.128
# 22                         0.433       0.074                      0.073
# 26                         0.535       0.175                      0.078

# %%
df_2019_north_america.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count     12.000000    12.0        12.000000       12.000000       12.000000
# mean      45.000000  2019.0         6.151583        0.929167        1.317250
# std       38.031088     0.0         0.971130        0.313356        0.219328
# min        9.000000  2019.0         3.597000        0.323000        0.688000
# 25%       22.000000  2019.0         5.882500        0.769000        1.262250
# 50%       33.000000  2019.0         6.287000        0.923000        1.363000
# 75%       56.750000  2019.0         6.669250        1.089750        1.445750
# max      147.000000  2019.0         7.278000        1.433000        1.505000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                12.000000                     12.000000   12.000000
# mean                  0.825333                      0.455417    0.187083
# std                   0.143633                      0.144163    0.103258
# min                   0.449000                      0.026000    0.074000
# 25%                   0.786500                      0.434500    0.108500
# 50%                   0.833000                      0.493500    0.159500
# 75%                   0.883000                      0.520750    0.254500
# max                   1.039000                      0.584000    0.419000
#
#        Perceptions_of_corruption
# count                  12.000000
# mean                    0.104333
# std                     0.070308
# min                     0.028000
# 25%                     0.073750
# 50%                     0.085500
# 75%                     0.114250
# max                     0.308000

# %%
df_2019_oceania = df_2019[df_2019['Continent']=='Oceania']

# %%
df_2019_oceania.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#         Country  Overall_rank  Year Continent  Happiness_score  \
# 7   New Zealand             8  2019   Oceania            7.307
# 10    Australia            11  2019   Oceania            7.228
#
#     GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 7            1.303           1.557                    1.026
# 10           1.372           1.548                    1.036
#
#     Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 7                          0.585       0.330                       0.38
# 10                         0.557       0.332                       0.29

# %%
df_2019_oceania.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count       2.00000     2.0         2.000000         2.00000        2.000000
# mean        9.50000  2019.0         7.267500         1.33750        1.552500
# std         2.12132     0.0         0.055861         0.04879        0.006364
# min         8.00000  2019.0         7.228000         1.30300        1.548000
# 25%         8.75000  2019.0         7.247750         1.32025        1.550250
# 50%         9.50000  2019.0         7.267500         1.33750        1.552500
# 75%        10.25000  2019.0         7.287250         1.35475        1.554750
# max        11.00000  2019.0         7.307000         1.37200        1.557000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                 2.000000                      2.000000    2.000000
# mean                  1.031000                      0.571000    0.331000
# std                   0.007071                      0.019799    0.001414
# min                   1.026000                      0.557000    0.330000
# 25%                   1.028500                      0.564000    0.330500
# 50%                   1.031000                      0.571000    0.331000
# 75%                   1.033500                      0.578000    0.331500
# max                   1.036000                      0.585000    0.332000
#
#        Perceptions_of_corruption
# count                    2.00000
# mean                     0.33500
# std                      0.06364
# min                      0.29000
# 25%                      0.31250
# 50%                      0.33500
# 75%                      0.35750
# max                      0.38000

# %%
df_2019_south_america = df_2019[df_2019['Continent']=='South America']

# %%
df_2019_south_america.sort_values(by='Happiness_score', ascending=False).head()
# Out:
#               Country  Overall_rank  Year      Continent  Happiness_score  \
# 25              Chile            26  2019  South America            6.444
# 31             Brazil            32  2019  South America            6.300
# 32            Uruguay            33  2019  South America            6.293
# 38  Trinidad & Tobago            39  2019  South America            6.192
# 42           Colombia            43  2019  South America            6.125
#
#     GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 25           1.159           1.369                    0.920
# 31           1.004           1.439                    0.802
# 32           1.124           1.465                    0.891
# 38           1.231           1.477                    0.713
# 42           0.985           1.410                    0.841
#
#     Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 25                         0.357       0.187                      0.056
# 31                         0.390       0.099                      0.086
# 32                         0.523       0.127                      0.150
# 38                         0.489       0.185                      0.016
# 42                         0.470       0.099                      0.034

# %%
df_2019_south_america.describe()
# Out:
#        Overall_rank    Year  Happiness_score  GDP_per_capita  Social_support  \
# count     11.000000    11.0        11.000000       11.000000       11.000000
# mean      51.545455  2019.0         5.944909        1.005273        1.389909
# std       22.848911     0.0         0.477370        0.135854        0.088935
# min       26.000000  2019.0         4.707000        0.776000        1.209000
# 25%       36.000000  2019.0         5.761000        0.936000        1.340500
# 50%       47.000000  2019.0         6.086000        0.985000        1.427000
# 75%       62.000000  2019.0         6.242500        1.108000        1.452000
# max      108.000000  2019.0         6.444000        1.231000        1.477000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count                11.000000                     11.000000   11.000000
# mean                  0.823455                      0.439273    0.123364
# std                   0.070267                      0.107906    0.046220
# min                   0.706000                      0.154000    0.064000
# 25%                   0.789500                      0.422500    0.091000
# 50%                   0.841000                      0.471000    0.126000
# 75%                   0.874500                      0.504500    0.160500
# max                   0.920000                      0.523000    0.187000
#
#        Perceptions_of_corruption
# count                  11.000000
# mean                    0.063364
# std                     0.037125
# min                     0.016000
# 25%                     0.040500
# 50%                     0.056000
# 75%                     0.083000
# max                     0.150000

# %%
df_2019[df_2019.GDP_per_capita == 0]
# Out:
#      Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 111  Somalia           112  2019    Africa            4.668             0.0
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 111           0.698                    0.268                         0.559
#
#      Generosity  Perceptions_of_corruption
# 111       0.243                       0.27

# %%
#Per https://www.macrotrends.net/countries/SOM/somalia/gdp-per-capita
#From 2017 to 2019, there was a 7.49 GDP increase
#Increased value = 0.022643 + 0.022643 * 0.0749
#Increased value = 0.022643 + 0.0016948507
#Increased value ≈ 0.0243378507

#Somalia 2019 GDP = 0.0243378507
df_2019.loc[df_2019['Country'] == 'Somalia', 'GDP_per_capita'] = 0.0243378507

# %%
df_2019[df_2019.Social_support == 0]
#No other data to use for Social_support
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 154  Central African Republic           155  2019    Africa            3.083
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 154           0.026             0.0                    0.105
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 154                         0.225       0.235                      0.035

# %%
df_2019[df_2019.Healthy_life_expectancy == 0]
# Out:
#        Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 134  Swaziland           135  2019    Africa            4.212           0.811
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 134           1.149                      0.0                         0.313
#
#      Generosity  Perceptions_of_corruption
# 134       0.074                      0.135

# %%
#df_2019[df_2019.Healthy_life_expectancy == 0]
#can use 2015 healthy_life_expectancy of 0.07566
#df_2015[df_2015['Country'] == 'Swaziland']
df_2019.loc[df_2019['Country'] == 'Swaziland', 'Healthy_life_expectancy'] = 0.07566

# %%
df_2019[df_2019.Freedom_to_make_life_choices == 0]
# Out:
#          Country  Overall_rank  Year Continent  Happiness_score  \
# 153  Afghanistan           154  2019      Asia            3.203
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 153            0.35           0.517                    0.361
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 153                           0.0       0.158                      0.025

# %%
#can use 2018 Freedom_to_make_life_choices of .085
#df_2018[df_2018['Country'] == 'Afghanistan']
df_2019.loc[df_2019['Country'] == 'Afghanistan', 'Freedom_to_make_life_choices'] = .085

# %%
df_2019[df_2019.Generosity == 0]
#No other data to use for Generosity
# Out:
#    Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 81  Greece            82  2019    Europe            5.287           1.181
#
#     Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 81           1.156                    0.999                         0.067
#
#     Generosity  Perceptions_of_corruption
# 81         0.0                      0.034

# %%
df_2019[df_2019.Perceptions_of_corruption == 0]
# Out:
#     Country  Overall_rank  Year Continent  Happiness_score  GDP_per_capita  \
# 70  Moldova            71  2019    Europe            5.529           0.685
#
#     Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 70           1.328                    0.739                         0.245
#
#     Generosity  Perceptions_of_corruption
# 70       0.181                        0.0

# %%
#df_2019[df_2019.Perceptions_of_corruption == 0]
#From 2017(0.010091) & 2016(0.01903). Average was taken to calculate 2019 perception of corruption
#avg = 0.0145605
df_2019.loc[df_2019['Country'] == 'Moldova', 'Perceptions_of_corruption'] = 0.0145605

# %%
#Healthy_Life_expectancy, GDP_per_capita and Freedom_to_make_life_choices are positively correlated to overall_rank

# %%
#first sorting by continent, then GDP_per_capital, then sorting by values in GDP_per_capita

df_2019.sort_values(['Happiness_score'], ascending = False)

#Of all continents, Africa has a lower overall Happiness_score. Now we look into what factors impact this
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 0                     Finland             1  2019    Europe            7.769
# 1                     Denmark             2  2019    Europe            7.600
# 2                      Norway             3  2019    Europe            7.554
# 3                     Iceland             4  2019    Europe            7.494
# 4                 Netherlands             5  2019    Europe            7.488
# ..                        ...           ...   ...       ...              ...
# 151                    Rwanda           152  2019    Africa            3.334
# 152                  Tanzania           153  2019    Africa            3.231
# 153               Afghanistan           154  2019      Asia            3.203
# 154  Central African Republic           155  2019    Africa            3.083
# 155               South Sudan           156  2019    Africa            2.853
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 0             1.340           1.587                    0.986
# 1             1.383           1.573                    0.996
# 2             1.488           1.582                    1.028
# 3             1.380           1.624                    1.026
# 4             1.396           1.522                    0.999
# ..              ...             ...                      ...
# 151           0.359           0.711                    0.614
# 152           0.476           0.885                    0.499
# 153           0.350           0.517                    0.361
# 154           0.026           0.000                    0.105
# 155           0.306           0.575                    0.295
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 151                         0.555       0.217                      0.411
# 152                         0.417       0.276                      0.147
# 153                         0.085       0.158                      0.025
# 154                         0.225       0.235                      0.035
# 155                         0.010       0.202                      0.091
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['GDP_per_capita','Happiness_score'], ascending = True)
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 111                   Somalia           112  2019    Africa            4.668
# 154  Central African Republic           155  2019    Africa            3.083
# 144                   Burundi           145  2019    Africa            3.775
# 140                   Liberia           141  2019    Africa            3.975
# 126          Congo (Kinshasa)           127  2019    Africa            4.418
# ..                        ...           ...   ...       ...              ...
# 50                     Kuwait            51  2019      Asia            6.021
# 20       United Arab Emirates            21  2019      Asia            6.825
# 33                  Singapore            34  2019      Asia            6.262
# 13                 Luxembourg            14  2019    Europe            7.090
# 28                      Qatar            29  2019      Asia            6.374
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 111        0.024338           0.698                    0.268
# 154        0.026000           0.000                    0.105
# 144        0.046000           0.447                    0.380
# 140        0.073000           0.922                    0.443
# 126        0.094000           1.125                    0.357
# ..              ...             ...                      ...
# 50         1.500000           1.319                    0.808
# 20         1.503000           1.310                    0.825
# 33         1.572000           1.463                    1.141
# 13         1.609000           1.479                    1.012
# 28         1.684000           1.313                    0.871
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 111                         0.559       0.243                      0.270
# 154                         0.225       0.235                      0.035
# 144                         0.220       0.176                      0.180
# 140                         0.370       0.233                      0.033
# 126                         0.269       0.212                      0.053
# ..                            ...         ...                        ...
# 50                          0.493       0.142                      0.097
# 20                          0.598       0.262                      0.182
# 33                          0.556       0.271                      0.453
# 13                          0.526       0.194                      0.316
# 28                          0.555       0.220                      0.167
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['Social_support', 'Happiness_score'], ascending = True)
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 154  Central African Republic           155  2019    Africa            3.083
# 148                     Syria           149  2019      Asia            3.462
# 101                     Benin           102  2019    Africa            4.883
# 144                   Burundi           145  2019    Africa            3.775
# 153               Afghanistan           154  2019      Asia            3.203
# ..                        ...           ...   ...       ...              ...
# 7                 New Zealand             8  2019   Oceania            7.307
# 1                     Denmark             2  2019    Europe            7.600
# 2                      Norway             3  2019    Europe            7.554
# 0                     Finland             1  2019    Europe            7.769
# 3                     Iceland             4  2019    Europe            7.494
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 154           0.026           0.000                    0.105
# 148           0.619           0.378                    0.440
# 101           0.393           0.437                    0.397
# 144           0.046           0.447                    0.380
# 153           0.350           0.517                    0.361
# ..              ...             ...                      ...
# 7             1.303           1.557                    1.026
# 1             1.383           1.573                    0.996
# 2             1.488           1.582                    1.028
# 0             1.340           1.587                    0.986
# 3             1.380           1.624                    1.026
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 154                         0.225       0.235                      0.035
# 148                         0.013       0.331                      0.141
# 101                         0.349       0.175                      0.082
# 144                         0.220       0.176                      0.180
# 153                         0.085       0.158                      0.025
# ..                            ...         ...                        ...
# 7                           0.585       0.330                      0.380
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 0                           0.596       0.153                      0.393
# 3                           0.591       0.354                      0.118
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['Healthy_life_expectancy','Happiness_score'], ascending = True)
# Out:
#                       Country  Overall_rank  Year Continent  Happiness_score  \
# 134                 Swaziland           135  2019    Africa            4.212
# 154  Central African Republic           155  2019    Africa            3.083
# 143                   Lesotho           144  2019    Africa            3.802
# 131                      Chad           132  2019    Africa            4.350
# 98                Ivory Coast            99  2019    Africa            4.944
# ..                        ...           ...   ...       ...              ...
# 5                 Switzerland             6  2019    Europe            7.480
# 29                      Spain            30  2019    Europe            6.354
# 57                      Japan            58  2019      Asia            5.886
# 75                  Hong Kong            76  2019      Asia            5.430
# 33                  Singapore            34  2019      Asia            6.262
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 134           0.811           1.149                  0.07566
# 154           0.026           0.000                  0.10500
# 143           0.489           1.169                  0.16800
# 131           0.350           0.766                  0.19200
# 98            0.569           0.808                  0.23200
# ..              ...             ...                      ...
# 5             1.452           1.526                  1.05200
# 29            1.286           1.484                  1.06200
# 57            1.327           1.419                  1.08800
# 75            1.438           1.277                  1.12200
# 33            1.572           1.463                  1.14100
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 134                         0.313       0.074                      0.135
# 154                         0.225       0.235                      0.035
# 143                         0.359       0.107                      0.093
# 131                         0.174       0.198                      0.078
# 98                          0.352       0.154                      0.090
# ..                            ...         ...                        ...
# 5                           0.572       0.263                      0.343
# 29                          0.362       0.153                      0.079
# 57                          0.445       0.069                      0.140
# 75                          0.440       0.258                      0.287
# 33                          0.556       0.271                      0.453
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['Freedom_to_make_life_choices', 'Happiness_score'], ascending = True)
# Out:
#                   Country  Overall_rank  Year      Continent  Happiness_score  \
# 155           South Sudan           156  2019         Africa            2.853
# 148                 Syria           149  2019           Asia            3.462
# 146                 Haiti           147  2019  North America            3.597
# 121            Mauritania           122  2019         Africa            4.490
# 81                 Greece            82  2019         Europe            5.287
# ..                    ...           ...   ...            ...              ...
# 0                 Finland             1  2019         Europe            7.769
# 20   United Arab Emirates            21  2019           Asia            6.825
# 2                  Norway             3  2019         Europe            7.554
# 108              Cambodia           109  2019           Asia            4.700
# 40             Uzbekistan            41  2019           Asia            6.174
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 155           0.306           0.575                    0.295
# 148           0.619           0.378                    0.440
# 146           0.323           0.688                    0.449
# 121           0.570           1.167                    0.489
# 81            1.181           1.156                    0.999
# ..              ...             ...                      ...
# 0             1.340           1.587                    0.986
# 20            1.503           1.310                    0.825
# 2             1.488           1.582                    1.028
# 108           0.574           1.122                    0.637
# 40            0.745           1.529                    0.756
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 155                         0.010       0.202                      0.091
# 148                         0.013       0.331                      0.141
# 146                         0.026       0.419                      0.110
# 121                         0.066       0.106                      0.088
# 81                          0.067       0.000                      0.034
# ..                            ...         ...                        ...
# 0                           0.596       0.153                      0.393
# 20                          0.598       0.262                      0.182
# 2                           0.603       0.271                      0.341
# 108                         0.609       0.232                      0.062
# 40                          0.631       0.322                      0.240
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['Generosity', 'Happiness_score'], ascending = True)
# Out:
#         Country  Overall_rank  Year      Continent  Happiness_score  \
# 81       Greece            82  2019         Europe            5.287
# 147    Botswana           148  2019         Africa            3.488
# 89   Azerbaijan            90  2019           Asia            5.208
# 88      Morocco            89  2019         Africa            5.208
# 118     Georgia           119  2019           Asia            4.519
# ..          ...           ...   ...            ...              ...
# 120       Kenya           121  2019         Africa            4.509
# 21        Malta            22  2019         Europe            6.726
# 146       Haiti           147  2019  North America            3.597
# 91    Indonesia            92  2019           Asia            5.192
# 130     Myanmar           131  2019           Asia            4.360
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 81            1.181           1.156                    0.999
# 147           1.041           1.145                    0.538
# 89            1.043           1.147                    0.769
# 88            0.801           0.782                    0.782
# 118           0.886           0.666                    0.752
# ..              ...             ...                      ...
# 120           0.512           0.983                    0.581
# 21            1.300           1.520                    0.999
# 146           0.323           0.688                    0.449
# 91            0.931           1.203                    0.660
# 130           0.710           1.181                    0.555
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 81                          0.067       0.000                      0.034
# 147                         0.455       0.025                      0.100
# 89                          0.351       0.035                      0.182
# 88                          0.418       0.036                      0.076
# 118                         0.346       0.043                      0.164
# ..                            ...         ...                        ...
# 120                         0.431       0.372                      0.053
# 21                          0.564       0.375                      0.151
# 146                         0.026       0.419                      0.110
# 91                          0.491       0.498                      0.028
# 130                         0.525       0.566                      0.172
#
# [156 rows x 11 columns]

# %%
df_2019.sort_values(['Perceptions_of_corruption', 'Happiness_score'], ascending = True)
# Out:
#                     Country  Overall_rank  Year Continent  Happiness_score  \
# 96                 Bulgaria            97  2019    Europe            5.011
# 47                  Romania            48  2019    Europe            6.070
# 77   Bosnia and Herzegovina            78  2019    Europe            5.386
# 45                   Kosovo            46  2019    Europe            6.100
# 132                 Ukraine           133  2019    Europe            4.332
# ..                      ...           ...   ...       ...              ...
# 7               New Zealand             8  2019   Oceania            7.307
# 0                   Finland             1  2019    Europe            7.769
# 1                   Denmark             2  2019    Europe            7.600
# 151                  Rwanda           152  2019    Africa            3.334
# 33                Singapore            34  2019      Asia            6.262
#
#      GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 96            1.092           1.513                    0.815
# 47            1.162           1.232                    0.825
# 77            0.945           1.212                    0.845
# 45            0.882           1.232                    0.758
# 132           0.820           1.390                    0.739
# ..              ...             ...                      ...
# 7             1.303           1.557                    1.026
# 0             1.340           1.587                    0.986
# 1             1.383           1.573                    0.996
# 151           0.359           0.711                    0.614
# 33            1.572           1.463                    1.141
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 96                          0.311       0.081                      0.004
# 47                          0.462       0.083                      0.005
# 77                          0.212       0.263                      0.006
# 45                          0.489       0.262                      0.006
# 132                         0.178       0.187                      0.010
# ..                            ...         ...                        ...
# 7                           0.585       0.330                      0.380
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 151                         0.555       0.217                      0.411
# 33                          0.556       0.271                      0.453
#
# [156 rows x 11 columns]

# %%
continents = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']
happiness_score = [4.368289, 5.224442, 6.245000, 6.151583, 7.267500, 5.944909]

plt.bar(continents, happiness_score)
plt.ylabel('Happiness Score')
plt.title('Happiness Scores by Continent (2019)')
plt.xticks(rotation=45)
plt.bar(continents, happiness_score, color=['red', 'blue', 'green', 'orange', 'purple', 'pink'])


plt.show()

# %%
continent_scores = df_2019.groupby('Continent')['Happiness_score'].sum().sort_values(ascending = False)
continent_scores
# Out:
# Continent
# Europe           268.535
# Asia             224.651
# Africa           196.573
# North America     73.819
# South America     65.394
# Oceania           14.535
# Name: Happiness_score, dtype: float64

# %%
total_continent_scores = continent_scores.sum()
total_continent_scores
# Out:
# 843.507

# %%
continent_scores_percent = (continent_scores/total_continent_scores) * 100
continent_scores_percent
# Out:
# Continent
# Europe           31.835539
# Asia             26.632974
# Africa           23.304252
# North America     8.751439
# South America     7.752633
# Oceania           1.723163
# Name: Happiness_score, dtype: float64

# %%
labels = continent_scores_percent.index
labels
# Out:
# Index(['Europe', 'Asia', 'Africa', 'North America', 'South America',
#        'Oceania'],
#       dtype='object', name='Continent')

# %%
labels = ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania']
sizes = [23.3, 26.6, 31.8, 8.8, 7.8, 1.7]
colors = ['green', 'orange', 'blue', 'red', 'brown', 'purple']

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Happiness Scores by Continent')
plt.show()

# %%
mean_continent_scores = df_2019.groupby('Continent')['Happiness_score'].mean()
mean_continent_scores
# Out:
# Continent
# Africa           4.368289
# Asia             5.224442
# Europe           6.245000
# North America    6.151583
# Oceania          7.267500
# South America    5.944909
# Name: Happiness_score, dtype: float64

# %%
labels = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']
sizes = [4.4, 5.2, 6.2, 6.2, 7.3, 5.9]
colors = ['green', 'orange', 'blue', 'red', 'purple', 'brown']

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Distribution of Mean Happiness Scores by Continent')
plt.show()
